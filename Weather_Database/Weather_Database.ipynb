# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
print(lat_lngs)
# Out:
# <zip object at 0x7fa860763680>

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
cities
# Out:
# ['hermanus',
#  'flinders',
#  'qaanaaq',
#  'arraial do cabo',
#  'rikitea',
#  'cidreira',
#  'kavieng',
#  'lata',
#  'yulara',
#  'arlit',
#  'bredasdorp',
#  'vostok',
#  'kaitangata',
#  'burayevo',
#  'kijang',
#  'busselton',
#  'saskylakh',
#  'bluff',
#  'barrow',
#  'yellowknife',
#  'tairua',
#  'mahebourg',
#  'svecha',
#  'atakpame',
#  'saint-philippe',
#  'kapaa',
#  'punta arenas',
#  'hithadhoo',
#  'albany',
#  'hay river',
#  'mataura',
#  'dingle',
#  'kirakira',
#  'vanimo',
#  'jamestown',
#  'elk city',
#  'barentsburg',
#  'valle de san juan',
#  'umzimvubu',
#  'lysva',
#  'mandal',
#  'portland',
#  'amderma',
#  'trabzon',
#  'kahului',
#  'carnarvon',
#  'ushuaia',
#  'lompoc',
#  'tiksi',
#  'castro',
#  'victoria',
#  'umm kaddadah',
#  'provideniya',
#  'puerto ayora',
#  'kasongo-lunda',
#  'mocambique',
#  'alofi',
#  'lagoa',
#  'cheyenne',
#  'the valley',
#  'bridlington',
#  'gamba',
#  'caravelas',
#  'east london',
#  'buchanan',
#  'evensk',
#  'rio gallegos',
#  'shelburne',
#  'bethel',
#  'grand river south east',
#  'yueyang',
#  'tuy hoa',
#  'taolanaro',
#  'aripuana',
#  'tura',
#  'esperance',
#  'sao filipe',
#  'san patricio',
#  'tsalenjikha',
#  'butaritari',
#  'ponta do sol',
#  'cape town',
#  'bandiagara',
#  'taltal',
#  'ambon',
#  'warqla',
#  'souillac',
#  'cherskiy',
#  'faya',
#  'ust-ilimsk',
#  'norman wells',
#  'mabaruma',
#  'meyungs',
#  'waingapu',
#  'pisco',
#  'mujiayingzi',
#  'guerrero negro',
#  'beloha',
#  'port elizabeth',
#  'seoul',
#  'upernavik',
#  'chuy',
#  'avarua',
#  'taksimo',
#  'yar-sale',
#  'henties bay',
#  'sukhumi',
#  'mandla',
#  'leningradskiy',
#  'kitimat',
#  'vanavara',
#  'tsumeb',
#  'luderitz',
#  'moree',
#  'tuatapere',
#  'mar del plata',
#  'otradnoye',
#  'tautira',
#  'mecca',
#  'nizhneyansk',
#  'bathsheba',
#  'kichera',
#  'puerto leguizamo',
#  'portel',
#  'hobart',
#  'fortuna',
#  'periyanegamam',
#  'kodiak',
#  'sawtell',
#  'itaqui',
#  'wanlaweyn',
#  'jalu',
#  'tsihombe',
#  'victor harbor',
#  'belushya guba',
#  'tres arroyos',
#  'hihifo',
#  'salta',
#  'lingyuan',
#  'ribeira grande',
#  'vaini',
#  'cabo san lucas',
#  'eirunepe',
#  'umea',
#  'sentyabrskiy',
#  'torbay',
#  'richards bay',
#  'talcahuano',
#  'sarankhola',
#  'ust-kamchatsk',
#  'iqaluit',
#  'tasiilaq',
#  'quelimane',
#  'rundu',
#  'ciudad bolivar',
#  'lillooet',
#  'ostrovnoy',
#  'sitka',
#  'dudinka',
#  'dikson',
#  'sistranda',
#  'salym',
#  'mookane',
#  'half moon bay',
#  'attawapiskat',
#  'bhunya',
#  'port macquarie',
#  'ascension',
#  'palasa',
#  'tikapur',
#  'merritt island',
#  'rungata',
#  'maniitsoq',
#  'avinurme',
#  'bambous virieux',
#  'kiruna',
#  'stonewall',
#  'nizwa',
#  'russell',
#  'gardez',
#  'juneau',
#  'nikolskoye',
#  'khuzhir',
#  'bardiyah',
#  'sarlat-la-caneda',
#  'hilo',
#  'barroso',
#  'zelion',
#  'guider',
#  'ucluelet',
#  'mys shmidta',
#  'ranong',
#  'illoqqortoormiut',
#  'zaria',
#  'gat',
#  'riohacha',
#  'aksarka',
#  'samalaeulu',
#  'gisborne',
#  'shingu',
#  'altagracia de orituco',
#  'chokurdakh',
#  'isla mujeres',
#  'zyryanka',
#  'kruisfontein',
#  'lingao',
#  'mahibadhoo',
#  'zhigansk',
#  'antalaha',
#  'kodinsk',
#  'chapais',
#  'port alfred',
#  'lolua',
#  'haradok',
#  'ust-bolsheretsk',
#  'kathmandu',
#  'isangel',
#  'laizhou',
#  'pionerskiy',
#  'khatanga',
#  'hamina',
#  'ozgon',
#  'sangueya',
#  'gizo',
#  'gold coast',
#  'tabiauea',
#  'longyearbyen',
#  'mogadishu',
#  'berea',
#  'hambantota',
#  'nago',
#  'tagusao',
#  'kalabo',
#  'krasnoyarskiy',
#  'tabriz',
#  'namibe',
#  'waipawa',
#  'catamarca',
#  'monrovia',
#  'nangong',
#  'geraldton',
#  'krasnoselkup',
#  'nuuk',
#  'siparia',
#  'saint anthony',
#  'corowa',
#  'bengkulu',
#  'caceres',
#  'auki',
#  'yining',
#  'banda aceh',
#  'luwuk',
#  'bur gabo',
#  'taicheng',
#  'baykit',
#  'mrirt',
#  'taoudenni',
#  'kanigoro',
#  'karratha',
#  'tumannyy',
#  'kununurra',
#  'hami',
#  'kholmsk',
#  'srednekolymsk',
#  'constitucion',
#  'santa rosa',
#  'atambua',
#  'birao',
#  'burica',
#  'correntina',
#  'bundaberg',
#  'aksum',
#  'luanda',
#  'atuona',
#  'quatre cocos',
#  'tignere',
#  'thompson',
#  'katsuura',
#  'saint-joseph',
#  'south lake tahoe',
#  'naryan-mar',
#  'copiapo',
#  'jaffna',
#  'jingdezhen',
#  'alyangula',
#  'mehamn',
#  'saint george',
#  'nuoro',
#  'naze',
#  'chagda',
#  'pevek',
#  'san jose',
#  'itoman',
#  'portobelo',
#  'yumen',
#  'grindavik',
#  'sorland',
#  'tatawin',
#  'celestun',
#  'ponte de sor',
#  'daru',
#  'serdobsk',
#  'baruun-urt',
#  'bilma',
#  'kontagora',
#  'batemans bay',
#  'asau',
#  'bulawayo',
#  'metehara',
#  'phan rang',
#  'neyshabur',
#  'ust-kut',
#  'karkaralinsk',
#  'lavrentiya',
#  'calabozo',
#  'coolum beach',
#  'vila velha',
#  'vaitape',
#  'ulverstone',
#  'inderborskiy',
#  'sibolga',
#  'arman',
#  'karasjok',
#  'leh',
#  'joshimath',
#  'arkhangelos',
#  'bad orb',
#  'sunnyside',
#  'belaya gora',
#  'batagay',
#  'contamana',
#  'kamenskoye',
#  'kalispell',
#  'caborca',
#  'viedma',
#  'portsmouth',
#  'zhezkazgan',
#  'inhambane',
#  'azanka',
#  'new norfolk',
#  'nabire',
#  'laguna',
#  'gezing',
#  'nelson bay',
#  'port lincoln',
#  'robertsport',
#  'kaeo',
#  'vagur',
#  'krasnyy chikoy',
#  'fare',
#  'dunedin',
#  'mount gambier',
#  'chandbali',
#  'aklavik',
#  'fort-shevchenko',
#  'fairbanks',
#  'saleaula',
#  'verkhnevilyuysk',
#  'avon park',
#  'tucuman',
#  'eureka',
#  'south hill',
#  'ugoofaaru',
#  'varska',
#  'kuminskiy',
#  'hokitika',
#  'marsa matruh',
#  'dzilam gonzalez',
#  'mehran',
#  'saint-pierre',
#  'jonkoping',
#  'palmer',
#  'saint-augustin',
#  'talara',
#  'poshtove',
#  'lorengau',
#  'kenora',
#  'chaupimarca',
#  'harper',
#  'tiznit',
#  'haverfordwest',
#  'tuktoyaktuk',
#  'coquimbo',
#  'andevoranto',
#  'georgetown',
#  'broken hill',
#  'poum',
#  'sanok',
#  'jiazi',
#  'college',
#  'miri',
#  'wufeng',
#  'manga',
#  'faanui',
#  'navahrudak',
#  'severo-kurilsk',
#  'kazalinsk',
#  'bafq',
#  'navalgund',
#  'sarangani',
#  'kingaroy',
#  'itaperucu',
#  'pacasmayo',
#  'goianesia',
#  'tazovskiy',
#  'colonia',
#  'mnogovershinnyy',
#  'mandalgovi',
#  'ridgecrest',
#  'aflu',
#  'barawe',
#  'farah',
#  'venado tuerto',
#  'ampanihy',
#  'olafsvik',
#  'pacific grove',
#  'cayenne',
#  'basco',
#  'oyem',
#  'salinopolis',
#  'banepa',
#  'galiwinku',
#  'nalut',
#  'oga',
#  'krasnogvardeyskoye',
#  'ailigandi',
#  'boo',
#  'krzeszowice',
#  'marcona',
#  'obuasi',
#  'satitoa',
#  'neepawa',
#  'dorado',
#  'iwanai',
#  'lebu',
#  'baijiantan',
#  'tumarbong',
#  'yeletskiy',
#  'fomboni',
#  'tarudant',
#  'anastacio',
#  'roald',
#  'aykhal',
#  'puerto colombia',
#  'camopi',
#  'petropavlovsk-kamchatskiy',
#  'airai',
#  'nargana',
#  'marawi',
#  'agalatovo',
#  'picayune',
#  'holland',
#  'dubovka',
#  'artyk',
#  'pangnirtung',
#  'biograd na moru',
#  'minot',
#  'gazimurskiy zavod',
#  'sulangan',
#  'moose factory',
#  'vaitupu',
#  'rwamagana',
#  'aswan',
#  'phan thiet',
#  'dali',
#  'ust-tsilma',
#  'comodoro rivadavia',
#  'grants pass',
#  'nishihara',
#  'urusha',
#  'chicama',
#  'talnakh',
#  'aljezur',
#  'aracati',
#  'sun valley',
#  'eskasem',
#  'carira',
#  'lobito',
#  'khagrachari',
#  'ta khmau',
#  'meulaboh',
#  'zhuanghe',
#  'ashland',
#  'bansko',
#  'burkhala',
#  'saint-denis',
#  'ambanja',
#  'salalah',
#  'bolonchen',
#  'batsfjord',
#  'laytown',
#  'turukhansk',
#  'touros',
#  'prince rupert',
#  'labuhan',
#  'isiolo',
#  'magdalena',
#  'mandera',
#  'balkanabat',
#  'feijo',
#  'louisbourg',
#  'rabupura',
#  'oranjestad',
#  'kurilsk',
#  'skalistyy',
#  'te anau',
#  'nguruka',
#  'sao joao da barra',
#  'lima',
#  'rawannawi',
#  'palabuhanratu',
#  'agadez',
#  'twentynine palms',
#  'dolores hidalgo',
#  'tahta',
#  'kushima',
#  'orlik',
#  'duz',
#  'ilebo',
#  'porto velho',
#  'hanyang',
#  'sofiysk',
#  'itaberai',
#  'chitral',
#  'kalmunai',
#  'nanortalik',
#  'natal',
#  'lhokseumawe',
#  'luganville',
#  'jizan',
#  'fort nelson',
#  'piedras negras',
#  'sembakung',
#  'muroto',
#  'zholymbet',
#  'temaraia',
#  'dicabisagan',
#  'jipijapa',
#  'anton lizardo',
#  'nanakuli',
#  'port hedland',
#  'kajaani',
#  'hamilton',
#  'tshela',
#  'izhma',
#  'awbari',
#  'altamira',
#  'narasannapeta',
#  'brooks',
#  'kikwit',
#  'erie',
#  'galgani',
#  'metro',
#  'srednebelaya',
#  'rio grande',
#  'sinkat',
#  'qaqortoq',
#  'nesna',
#  'komsomolskiy',
#  'sabak',
#  'grand gaube',
#  'merauke',
#  'hit',
#  'wakkanai',
#  'havoysund',
#  'codrington',
#  'zaranj',
#  'liberal',
#  'mayumba',
#  'donauworth',
#  'roma',
#  'port hardy',
#  'ouallam',
#  'moerai',
#  'lincoln',
#  'anadyr',
#  'ust-nera',
#  'brae',
#  'mudyuga',
#  'kota belud',
#  'hovd',
#  'pskov',
#  'kita',
#  'camana',
#  'sangmelima',
#  'ixtapa',
#  'deputatskiy',
#  'bandundu',
#  'weiz',
#  'key west',
#  'kantunilkin',
#  'nueva guinea',
#  'akdepe',
#  'zhangye',
#  'guantanamo',
#  'nicolas bravo',
#  'samarai',
#  'smithers',
#  'mangaluru',
#  'margate',
#  'tessalit',
#  'mega',
#  'aquiles serdan',
#  'padang',
#  'hockenheim',
#  'honiara',
#  'sola',
#  'bagotville',
#  'general roca',
#  'sena madureira',
#  'miles city',
#  'grootfontein',
#  'acajutla',
#  'axim',
#  'bousso',
#  'klaksvik',
#  'babanusah',
#  'cuza voda',
#  'gorno-chuyskiy',
#  'coihaique',
#  'sudak',
#  'sorong',
#  'farakka',
#  'chiclana',
#  'nemuro',
#  'surab',
#  'marienburg',
#  'nome',
#  'cheuskiny',
#  'clarence town',
#  'yerbogachen',
#  'miramar',
#  'kuryk',
#  'mount isa',
#  'paragominas',
#  'tame',
#  'oktyabrskoye',
#  'wahran',
#  'abu dhabi',
#  'clyde river',
#  'cobija',
#  'paraopeba',
#  'bay roberts',
#  'butembo',
#  'ambilobe',
#  'semey',
#  'nombre de dios',
#  'jujuy',
#  'beringovskiy',
#  'shimoda',
#  'kamaishi',
#  'florianopolis',
#  'natalinsk',
#  'wajima',
#  'kathu',
#  'san juan',
#  'labutta',
#  'sakakah',
#  'yingzhong',
#  'namatanai',
#  'san quintin',
#  'novyy urengoy',
#  'vikhorevka',
#  'loreto',
#  'malanje',
#  'carutapera',
#  'sozimskiy',
#  'altus',
#  'bolungarvik',
#  'hirara',
#  'bacolod',
#  'ardistan',
#  'longlac',
#  'guelengdeng',
#  'santa fe',
#  'porto santo',
#  'gilgit',
#  'ouagadougou',
#  'mpika',
#  'ushtobe',
#  'vestmanna',
#  'itarema',
#  'karaul',
#  'terre haute',
#  'moron',
#  'awjilah',
#  'los llanos de aridane',
#  'changji',
#  'clinton',
#  'oktyabrskiy',
#  'vallenar',
#  'athabasca',
#  'havre-saint-pierre',
#  'santa cruz',
#  'brainerd',
#  'manyana',
#  'champerico',
#  'bukoba',
#  'kudahuvadhoo',
#  'berlevag',
#  'jeremoabo',
#  'dongsheng',
#  'viesite',
#  'atar',
#  'narsaq',
#  'eravur',
#  'frontera comalapa',
#  'las varas',
#  'pietermaritzburg',
#  'viligili',
#  'coxim',
#  'ovalle',
#  'sainte-suzanne',
#  'shaunavon',
#  'dahra',
#  'maceio',
#  'markova',
#  'woodward',
#  'progreso',
#  'san juan bautista',
#  'ponta delgada',
#  'centralia',
#  'sept-iles',
#  'zonguldak',
#  'asahikawa',
#  'tezu',
#  'verkhoyansk',
#  'guadalupe',
#  'antofagasta',
#  'bumbuna',
#  'najran',
#  'eyl',
#  'storforshei',
#  'husavik',
#  'kungurtug',
#  'port hawkesbury',
#  'ahipara',
#  'blagoyevo',
#  'puerto gaitan',
#  'vila franca do campo',
#  'agen',
#  'kunming',
#  'goderich',
#  'samusu',
#  'tilichiki',
#  'amahai',
#  'sambava',
#  'belyy yar',
#  'sicuani',
#  'killybegs',
#  'sao jose da coroa grande',
#  'khasan',
#  'kupang',
#  'rujewa',
#  'kavaratti',
#  'amapa',
#  'hinton',
#  'olovyannaya',
#  'pailon',
#  'benguela',
#  'ketchikan',
#  'nicoya',
#  'lossiemouth',
#  'gallup',
#  'sri aman',
#  'mwinilunga',
#  'odweyne',
#  'oistins',
#  'hakui',
#  'parrita',
#  'longyan',
#  'itatiaia',
#  'ferme-neuve',
#  'omachi',
#  'saint albans',
#  'sinnamary',
#  'giyani',
#  'bonavista',
#  'varhaug',
#  'paracuru',
#  'bongandanga']

# %%
len(cities)
# Out:
# 781

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
#

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=63773b8ed321df9b1aca6032f18b2605

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "laguna"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=63773b8ed321df9b1aca6032f18b2605&q=laguna

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data
# Out:
# {'coord': {'lon': -121.4238, 'lat': 38.421},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 75.24,
#   'feels_like': 73.81,
#   'temp_min': 71.46,
#   'temp_max': 78.3,
#   'pressure': 1015,
#   'humidity': 29},
#  'visibility': 10000,
#  'wind': {'speed': 18.41, 'deg': 340},
#  'clouds': {'all': 0},
#  'dt': 1655144690,
#  'sys': {'type': 2,
#   'id': 2034215,
#   'country': 'US',
#   'sunrise': 1655124080,
#   'sunset': 1655177424},
#  'timezone': -25200,
#  'id': 5364271,
#  'name': 'Laguna',
#  'cod': 200}

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "laguna"
print(city_url)
l = requests.get(city_url).json()
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=63773b8ed321df9b1aca6032f18b2605&q=laguna

# %%
print(l["weather"][0]["description"])
# Out:
# clear sky

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
print(cities)
# Out:
# ['ushuaia', 'albany', 'hilo', 'fortuna', 'carnarvon', 'makakilo city', 'nemuro', 'punta arenas', 'loei', 'new norfolk', 'darnah', 'hami', 'grand river south east', 'baoying', 'olafsvik', 'vao', 'butembo', 'porto walter', 'mar del plata', 'patnongon', 'barrow', 'mataura', 'ribeira grande', 'chernyshevskiy', 'avarua', 'kenai', 'bredasdorp', 'rikitea', 'taolanaro', 'babanusah', 'tuktoyaktuk', 'jumla', 'mys shmidta', 'ponta do sol', 'busselton', 'santa marinella', 'tougue', 'hobart', 'atuona', 'puerto ayora', 'nouadhibou', 'agadez', 'coquimbo', 'zhigansk', 'touros', 'upernavik', 'kavaratti', 'olinda', 'tanggu', 'yar', 'marzuq', 'bluff', 'meulaboh', 'doka', 'samusu', 'darab', 'gabu', 'port elizabeth', 'lumphat', 'kavieng', 'ampanihy', 'lompoc', 'nizhneyansk', 'san patricio', 'yellowknife', 'saskylakh', 'guru har sahai', 'lagoa', 'amderma', 'port alfred', 'changji', 'buchanan', 'flin flon', 'havelock', 'cuyotenango', 'esperance', 'chokurdakh', 'san policarpo', 'qaanaaq', 'bairiki', 'jian', 'alice springs', 'praia', 'georgetown', 'baringo', 'kahului', 'puerto escondido', 'bemidji', 'lamu', 'piacabucu', 'mala vyska', 'bengkulu', 'yar-sale', 'illoqqortoormiut', 'palabuhanratu', 'oyem', 'ayan', 'chuy', 'van', 'tessalit', 'aksu', 'arraial do cabo', 'ancud', 'dikson', 'hithadhoo', 'satitoa', 'aklavik', 'novyy urengoy', 'luanda', 'brae', 'saint-philippe', 'pauini', 'kisangani', 'pitsunda', 'faanui', 'awbari', 'anadyr', 'zhanakorgan', 'ziyang', 'turukhansk', 'tabas', 'port hedland', 'kirakira', 'north branch', 'glyadyanskoye', 'cherskiy', 'alofi', 'cape town', 'tiksi', 'ilulissat', 'ust-kuyga', 'aitape', 'fergus falls', 'toliary', 'boddam', 'hermanus', 'cururupu', 'medina', 'vostok', 'coracao de jesus', 'cidreira', 'bouar', 'provideniya', 'coihaique', 'xuddur', 'pevek', 'codrington', 'kapaa', 'tooele', 'poya', 'serenje', 'grand gaube', 'canitas', 'general pico', 'denizli', 'avera', 'sisimiut', 'severo-kurilsk', 'storforshei', 'itoman', 'la asuncion', 'prince albert', 'baykit', 'granard', 'marcona', 'vaitupu', 'jamestown', 'kupang', 'lavrentiya', 'college', 'belushya guba', 'lolua', 'basoko', 'flinders', 'semey', 'roald', 'ahipara', 'ullapool', 'bandarbeyla', 'kaitangata', 'krasnoselkup', 'sinjar', 'axim', 'broken hill', 'luderitz', 'gamba', 'laguna', 'palmer', 'ouadda', 'tabou', 'popondetta', 'requena', 'salalah', 'dingli', 'natal', 'kodiak', 'saint george', 'vanimo', 'vaini', 'tasiilaq', 'sibolga', 'hartsdale', 'clyde river', 'vila franca do campo', 'kalanguy', 'teahupoo', 'attawapiskat', 'gorkovskiy', 'kamaishi', 'the valley', 'bilma', 'bambous virieux', 'nanortalik', 'tamandare', 'klaksvik', 'nova serrana', 'naze', 'khormuj', 'san cristobal', 'venado tuerto', 'mogok', 'qingdao', 'portel', 'praxedis guerrero', 'hargeysa', 'gimli', 'marystown', 'mount gambier', 'pisco', 'isangel', 'kainantu', 'tramore', 'estacion coahuila', 'agua prieta', 'umm kaddadah', 'kanker', 'dano', 'panixtlahuaca', 'chagda', 'santiago del estero', 'faya', 'ocampo', 'hobyo', 'khatanga', 'sorvag', 'uige', 'iqaluit', 'menongue', 'santa rosa', 'cockburn town', 'felanitx', 'naantali', 'moose factory', 'himora', 'bowen', 'kununurra', 'rio grande', 'hihifo', 'shingu', 'kristiansund', 'kloulklubed', 'beringovskiy', 'nicoya', 'saint-pierre', 'wajima', 'ormoz', 'yeppoon', 'yerbogachen', 'vila velha', 'nenagh', 'kilindoni', 'houma', 'sentyabrskiy', 'ngorongoro', 'suntar', 'mataruska banja', 'grado', 'villa bruzual', 'butaritari', 'lokosovo', 'norman wells', 'simplicio mendes', 'espinosa', 'kashi', 'anopino', 'dumas', 'goderich', 'barentsburg', 'evensk', 'libenge', 'ravar', 'auki', 'aksehir', 'tsihombe', 'paamiut', 'saldanha', 'anlu', 'poum', 'quballat', 'caravelas', 'el faiyum', 'machico', 'the pas', 'sindou', 'todos santos', 'klichka', 'odzaci', 'san quintin', 'verkh-usugli', 'kishangarh', 'gisborne', 'east london', 'rocha', 'lebu', 'tvoroyri', 'whitehorse', 'sabang', 'jaciara', 'ottawa', 'kruisfontein', 'lake havasu city', 'sao filipe', 'impfondo', 'millinocket', 'jurado', ' ...

# %%
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | fortuna
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | makakilo city
# Processing Record 7 of Set 1 | nemuro
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | loei
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | darnah
# Processing Record 12 of Set 1 | hami
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | baoying
# Processing Record 15 of Set 1 | olafsvik
# Processing Record 16 of Set 1 | vao
# Processing Record 17 of Set 1 | butembo
# Processing Record 18 of Set 1 | porto walter
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | patnongon
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | chernyshevskiy
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | kenai
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | jumla
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | santa marinella
# Processing Record 37 of Set 1 | tougue
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | nouadhibou
# Processing Record 42 of Set 1 | agadez
# Processing Record 43 of Set 1 | coquimbo
# Processing Record 44 of Set 1 | zhigansk
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | kavaratti
# Processing Record 48 of Set 1 | olinda
# Processing Record 49 of Set 1 | tanggu
# Processing Record 50 of Set 1 | yar
# Processing Record 1 of Set 2 | marzuq
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | meulaboh
# Processing Record 4 of Set 2 | doka
# Processing Record 5 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 2 | darab
# Processing Record 7 of Set 2 | gabu
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | lumphat
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | ampanihy
# Processing Record 12 of Set 2 | lompoc
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | guru har sahai
# Processing Record 18 of Set 2 | lagoa
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | changji
# Processing Record 22 of Set 2 | buchanan
# Processing Record 23 of Set 2 | flin flon
# Processing Record 24 of Set 2 | havelock
# Processing Record 25 of Set 2 | cuyotenango
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | san policarpo
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | bairiki
# Processing Record 31 of Set 2 | jian
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | praia
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | baringo
# Processing Record 36 of Set 2 | kahului
# Processing Record 37 of Set 2 | puerto escondido
# Processing Record 38 of Set 2 | bemidji
# Processing Record 39 of Set 2 | lamu
# Processing Record 40 of Set 2 | piacabucu
# Processing Record 41 of Set 2 | mala vyska
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | yar-sale
# Processing Record 44 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 2 | oyem
# Processing Record 47 of Set 2 | ayan
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | van
# Processing Record 50 of Set 2 | tessalit
# Processing Record 1 of Set 3 | aksu
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | novyy urengoy
# Processing Record 9 of Set 3 | luanda
# Processing Record 10 of Set 3 | brae
# Processing Record 11 of Set 3 | saint-philippe
# Processing Record 12 of Set 3 | pauini
# Processing Record 13 of Set 3 | kisangani
# Processing Record 14 of Set 3 | pitsunda
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | awbari
# Processing Record 17 of Set 3 | anadyr
# Processing Record 18 of Set 3 | zhanakorgan
# Processing Record 19 of Set 3 | ziyang
# Processing Record 20 of Set 3 | turukhansk
# Processing Record 21 of Set 3 | tabas
# Processing Record 22 of Set 3 | port hedland
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | north branch
# Processing Record 25 of Set 3 | glyadyanskoye
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | alofi
# Processing Record 28 of Set 3 | cape town
# Processing Record 29 of Set 3 | tiksi
# Processing Record 30 of Set 3 | ilulissat
# Processing Record 31 of Set 3 | ust-kuyga
# Processing Record 32 of Set 3 | aitape
# Processing Record 33 of Set 3 | fergus falls
# Processing Record 34 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 3 | boddam
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | cururupu
# Processing Record 38 of Set 3 | medina
# Processing Record 39 of Set 3 | vostok
# Processing Record 40 of Set 3 | coracao de jesus
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | bouar
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | xuddur
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | codrington
# Processing Record 48 of Set 3 | kapaa
# Processing Record 49 of Set 3 | tooele
# Processing Record 50 of Set 3 | poya
# Processing Record 1 of Set 4 | serenje
# Processing Record 2 of Set 4 | grand gaube
# Processing Record 3 of Set 4 | canitas
# City not found. Skipping...
# Processing Record 4 of Set 4 | general pico
# Processing Record 5 of Set 4 | denizli
# Processing Record 6 of Set 4 | avera
# Processing Record 7 of Set 4 | sisimiut
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | storforshei
# Processing Record 10 of Set 4 | itoman
# Processing Record 11 of Set 4 | la asuncion
# Processing Record 12 of Set 4 | prince albert
# Processing Record 13 of Set 4 | baykit
# Processing Record 14 of Set 4 | granard
# Processing Record 15 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 4 | jamestown
# Processing Record 18 of Set 4 | kupang
# Processing Record 19 of Set 4 | lavrentiya
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 4 | basoko
# Processing Record 24 of Set 4 | flinders
# Processing Record 25 of Set 4 | semey
# Processing Record 26 of Set 4 | roald
# Processing Record 27 of Set 4 | ahipara
# Processing Record 28 of Set 4 | ullapool
# Processing Record 29 of Set 4 | bandarbeyla
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | krasnoselkup
# Processing Record 32 of Set 4 | sinjar
# Processing Record 33 of Set 4 | axim
# Processing Record 34 of Set 4 | broken hill
# Processing Record 35 of Set 4 | luderitz
# Processing Record 36 of Set 4 | gamba
# Processing Record 37 of Set 4 | laguna
# Processing Record 38 of Set 4 | palmer
# Processing Record 39 of Set 4 | ouadda
# Processing Record 40 of Set 4 | tabou
# Processing Record 41 of Set 4 | popondetta
# Processing Record 42 of Set 4 | requena
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | dingli
# Processing Record 45 of Set 4 | natal
# Processing Record 46 of Set 4 | kodiak
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | vanimo
# Processing Record 49 of Set 4 | vaini
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | sibolga
# Processing Record 2 of Set 5 | hartsdale
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | kalanguy
# Processing Record 6 of Set 5 | teahupoo
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | gorkovskiy
# Processing Record 9 of Set 5 | kamaishi
# Processing Record 10 of Set 5 | the valley
# Processing Record 11 of Set 5 | bilma
# Processing Record 12 of Set 5 | bambous virieux
# Processing Record 13 of Set 5 | nanortalik
# Processing Record 14 of Set 5 | tamandare
# Processing Record 15 of Set 5 | klaksvik
# Processing Record 16 of Set 5 | nova serrana
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 19 of Set 5 | san cristobal
# Processing Record 20 of Set 5 | venado tuerto
# Processing Record 21 of Set 5 | mogok
# Processing Record 22 of Set 5 | qingdao
# Processing Record 23 of Set 5 | portel
# Processing Record 24 of Set 5 | praxedis guerrero
# Processing Record 25 of Set 5 | hargeysa
# Processing Record 26 of Set 5 | gimli
# Processing Record 27 of Set 5 | marystown
# Processing Record 28 of Set 5 | mount gambier
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | kainantu
# Processing Record 32 of Set 5 | tramore
# Processing Record 33 of Set 5 | estacion coahuila
# Processing Record 34 of Set 5 | agua prieta
# Processing Record 35 of Set 5 | umm kaddadah
# Processing Record 36 of Set 5 | kanker
# Processing Record 37 of Set 5 | dano
# Processing Record 38 of Set 5 | panixtlahuaca
# City not found. Skipping...
# Processing Record 39 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 5 | santiago del estero
# Processing Record 41 of Set 5 | faya
# Processing Record 42 of Set 5 | ocampo
# Processing Record 43 of Set 5 | hobyo
# Processing Record 44 of Set 5 | khatanga
# Processing Record 45 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 5 | uige
# Processing Record 47 of Set 5 | iqaluit
# Processing Record 48 of Set 5 | menongue
# Processing Record 49 of Set 5 | santa rosa
# Processing Record 50 of Set 5 | cockburn town
# Processing Record 1 of Set 6 | felanitx
# Processing Record 2 of Set 6 | naantali
# Processing Record 3 of Set 6 | moose factory
# Processing Record 4 of Set 6 | himora
# City not found. Skipping...
# Processing Record 5 of Set 6 | bowen
# Processing Record 6 of Set 6 | kununurra
# Processing Record 7 of Set 6 | rio grande
# Processing Record 8 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 6 | shingu
# Processing Record 10 of Set 6 | kristiansund
# Processing Record 11 of Set 6 | kloulklubed
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | nicoya
# Processing Record 14 of Set 6 | saint-pierre
# Processing Record 15 of Set 6 | wajima
# Processing Record 16 of Set 6 | ormoz
# Processing Record 17 of Set 6 | yeppoon
# Processing Record 18 of Set 6 | yerbogachen
# Processing Record 19 of Set 6 | vila velha
# Processing Record 20 of Set 6 | nenagh
# Processing Record 21 of Set 6 | kilindoni
# Processing Record 22 of Set 6 | houma
# Processing Record 23 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | ngorongoro
# Processing Record 25 of Set 6 | suntar
# Processing Record 26 of Set 6 | mataruska banja
# Processing Record 27 of Set 6 | grado
# Processing Record 28 of Set 6 | villa bruzual
# Processing Record 29 of Set 6 | butaritari
# Processing Record 30 of Set 6 | lokosovo
# Processing Record 31 of Set 6 | norman wells
# Processing Record 32 of Set 6 | simplicio mendes
# Processing Record 33 of Set 6 | espinosa
# Processing Record 34 of Set 6 | kashi
# Processing Record 35 of Set 6 | anopino
# Processing Record 36 of Set 6 | dumas
# Processing Record 37 of Set 6 | goderich
# Processing Record 38 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 6 | evensk
# Processing Record 40 of Set 6 | libenge
# Processing Record 41 of Set 6 | ravar
# Processing Record 42 of Set 6 | auki
# Processing Record 43 of Set 6 | aksehir
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | paamiut
# Processing Record 46 of Set 6 | saldanha
# Processing Record 47 of Set 6 | anlu
# Processing Record 48 of Set 6 | poum
# Processing Record 49 of Set 6 | quballat
# Processing Record 50 of Set 6 | caravelas
# Processing Record 1 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 2 of Set 7 | machico
# Processing Record 3 of Set 7 | the pas
# Processing Record 4 of Set 7 | sindou
# Processing Record 5 of Set 7 | todos santos
# Processing Record 6 of Set 7 | klichka
# Processing Record 7 of Set 7 | odzaci
# Processing Record 8 of Set 7 | san quintin
# Processing Record 9 of Set 7 | verkh-usugli
# Processing Record 10 of Set 7 | kishangarh
# Processing Record 11 of Set 7 | gisborne
# Processing Record 12 of Set 7 | east london
# Processing Record 13 of Set 7 | rocha
# Processing Record 14 of Set 7 | lebu
# Processing Record 15 of Set 7 | tvoroyri
# Processing Record 16 of Set 7 | whitehorse
# Processing Record 17 of Set 7 | sabang
# Processing Record 18 of Set 7 | jaciara
# Processing Record 19 of Set 7 | ottawa
# Processing Record 20 of Set 7 | kruisfontein
# Processing Record 21 of Set 7 | lake havasu city
# Processing Record 22 of Set 7 | sao filipe
# Processing Record 23 of Set 7 | impfondo
# Processing Record 24 of Set 7 | millinocket
# Processing Record 25 of Set 7 | jurado
# Processing Record 26 of Set 7 | la orilla
# Processing Record 27 of Set 7 | ust-kulom
# Processing Record 28 of Set 7 | billings
# Processing Record 29 of Set 7 | ust-maya
# Processing Record 30 of Set 7 | okhotsk
# Processing Record 31 of Set 7 | bima
# Processing Record 32 of Set 7 | mitsamiouli
# Processing Record 33 of Set 7 | kirac
# City not found. Skipping...
# Processing Record 34 of Set 7 | honningsvag
# Processing Record 35 of Set 7 | varhaug
# Processing Record 36 of Set 7 | nokaneng
# Processing Record 37 of Set 7 | samarai
# Processing Record 38 of Set 7 | nikolskoye
# Processing Record 39 of Set 7 | cuamba
# Processing Record 40 of Set 7 | valleyview
# Processing Record 41 of Set 7 | kendari
# Processing Record 42 of Set 7 | kosh-agach
# Processing Record 43 of Set 7 | broome
# Processing Record 44 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 7 | hastings
# Processing Record 46 of Set 7 | swan hill
# Processing Record 47 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 48 of Set 7 | barabinsk
# Processing Record 49 of Set 7 | presidencia roque saenz pena
# Processing Record 50 of Set 7 | namibe
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | castro
# Processing Record 3 of Set 8 | oum hadjer
# Processing Record 4 of Set 8 | ryotsu
# Processing Record 5 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 6 of Set 8 | malanje
# Processing Record 7 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 8 | constitucion
# Processing Record 9 of Set 8 | komsomolskiy
# Processing Record 10 of Set 8 | severodvinsk
# Processing Record 11 of Set 8 | northam
# Processing Record 12 of Set 8 | redding
# Processing Record 13 of Set 8 | bani walid
# Processing Record 14 of Set 8 | aswan
# Processing Record 15 of Set 8 | te anau
# Processing Record 16 of Set 8 | dunedin
# Processing Record 17 of Set 8 | hamilton
# Processing Record 18 of Set 8 | pangkalanbuun
# Processing Record 19 of Set 8 | luxeuil-les-bains
# Processing Record 20 of Set 8 | viedma
# Processing Record 21 of Set 8 | kisanga
# Processing Record 22 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 8 | barcelos
# Processing Record 24 of Set 8 | vlore
# Processing Record 25 of Set 8 | jaisalmer
# Processing Record 26 of Set 8 | richards bay
# Processing Record 27 of Set 8 | araouane
# Processing Record 28 of Set 8 | katobu
# Processing Record 29 of Set 8 | umm lajj
# Processing Record 30 of Set 8 | thompson
# Processing Record 31 of Set 8 | panagjuriste
# City not found. Skipping...
# Processing Record 32 of Set 8 | victoria
# Processing Record 33 of Set 8 | ahuimanu
# Processing Record 34 of Set 8 | havre-saint-pierre
# Processing Record 35 of Set 8 | gat
# Processing Record 36 of Set 8 | port hardy
# Processing Record 37 of Set 8 | mahebourg
# Processing Record 38 of Set 8 | mahibadhoo
# Processing Record 39 of Set 8 | kenora
# Processing Record 40 of Set 8 | cabo san lucas
# Processing Record 41 of Set 8 | humaita
# Processing Record 42 of Set 8 | tevriz
# Processing Record 43 of Set 8 | biak
# Processing Record 44 of Set 8 | blonduos
# City not found. Skipping...
# Processing Record 45 of Set 8 | neustadt
# Processing Record 46 of Set 8 | mporokoso
# Processing Record 47 of Set 8 | boissevain
# Processing Record 48 of Set 8 | sao joao da barra
# Processing Record 49 of Set 8 | nantucket
# Processing Record 50 of Set 8 | matucana
# Processing Record 1 of Set 9 | inta
# Processing Record 2 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 3 of Set 9 | qaqortoq
# Processing Record 4 of Set 9 | baikunthpur
# Processing Record 5 of Set 9 | yerkoy
# Processing Record 6 of Set 9 | keetmanshoop
# Processing Record 7 of Set 9 | kamsack
# Processing Record 8 of Set 9 | ati
# Processing Record 9 of Set 9 | warrington
# Processing Record 10 of Set 9 | straumen
# Processing Record 11 of Set 9 | maraa
# Processing Record 12 of Set 9 | bathsheba
# Processing Record 13 of Set 9 | torbay
# Processing Record 14 of Set 9 | sinnamary
# Processing Record 15 of Set 9 | amarpur
# Processing Record 16 of Set 9 | fatehpur
# Processing Record 17 of Set 9 | okato
# Processing Record 18 of Set 9 | cucuyagua
# Processing Record 19 of Set 9 | muli
# Processing Record 20 of Set 9 | omboue
# Processing Record 21 of Set 9 | acapulco
# Processing Record 22 of Set 9 | bushehr
# Processing Record 23 of Set 9 | hambantota
# Processing Record 24 of Set 9 | vestmannaeyjar
# Processing Record 25 of Set 9 | toronto
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | morant bay
# Processing Record 28 of Set 9 | bethel
# Processing Record 29 of Set 9 | nyimba
# Processing Record 30 of Set 9 | varna
# Processing Record 31 of Set 9 | razdolinsk
# Processing Record 32 of Set 9 | puerto plata
# Processing Record 33 of Set 9 | belyy yar
# Processing Record 34 of Set 9 | rio branco
# Processing Record 35 of Set 9 | winnemucca
# Processing Record 36 of Set 9 | karema
# Processing Record 37 of Set 9 | grass valley
# Processing Record 38 of Set 9 | moerai
# Processing Record 39 of Set 9 | srednekolymsk
# Processing Record 40 of Set 9 | laiwu
# Processing Record 41 of Set 9 | marsa matruh
# Processing Record 42 of Set 9 | chara
# Processing Record 43 of Set 9 | dakar
# Processing Record 44 of Set 9 | manggar
# Processing Record 45 of Set 9 | aguada de pasajeros
# Processing Record 46 of Set 9 | kulevcha
# Processing Record 47 of Set 9 | cayenne
# Processing Record 48 of Set 9 | osmena
# Processing Record 49 of Set 9 | kalabo
# Processing Record 50 of Set 9 | boa vista
# Processing Record 1 of Set 10 | tehachapi
# Processing Record 2 of Set 10 | egvekinot
# Processing Record 3 of Set 10 | takoradi
# Processing Record 4 of Set 10 | hasaki
# Processing Record 5 of Set 10 | belozerskoye
# Processing Record 6 of Set 10 | luganville
# Processing Record 7 of Set 10 | bilibino
# Processing Record 8 of Set 10 | del rio
# Processing Record 9 of Set 10 | pervomayskoye
# Processing Record 10 of Set 10 | dreux
# Processing Record 11 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 10 | qeshm
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | esso
# Processing Record 15 of Set 10 | veracruz
# Processing Record 16 of Set 10 | emerald
# Processing Record 17 of Set 10 | konya
# Processing Record 18 of Set 10 | songjianghe
# Processing Record 19 of Set 10 | goba
# Processing Record 20 of Set 10 | amurzet
# Processing Record 21 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 22 of Set 10 | maputo
# Processing Record 23 of Set 10 | jahanabad
# Processing Record 24 of Set 10 | ocozocoautla
# City not found. Skipping...
# Processing Record 25 of Set 10 | loreto
# Processing Record 26 of Set 10 | mantua
# Processing Record 27 of Set 10 | longyearbyen
# Processing Record 28 of Set 10 | arroyo
# Processing Record 29 of Set 10 | jardim
# Processing Record 30 of Set 10 | miles city
# Processing Record 31 of Set 10 | margate
# Processing Record 32 of Set 10 | fort-shevchenko
# Processing Record 33 of Set 10 | ostersund
# Processing Record 34 of Set 10 | touba
# Processing Record 35 of Set 10 | pierre
# Processing Record 36 of Set 10 | berlevag
# Processing Record 37 of Set 10 | tura
# Processing Record 38 of Set 10 | sheopur
# Processing Record 39 of Set 10 | briancon
# Processing Record 40 of Set 10 | port-gentil
# Processing Record 41 of Set 10 | cochrane
# Processing Record 42 of Set 10 | sioux lookout
# Processing Record 43 of Set 10 | vardo
# Processing Record 44 of Set 10 | bay roberts
# Processing Record 45 of Set 10 | ussuriysk
# Processing Record 46 of Set 10 | pangai
# Processing Record 47 of Set 10 | otane
# Processing Record 48 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 10 | kuybyshevskiy zaton
# Processing Record 50 of Set 10 | nishihara
# Processing Record 1 of Set 11 | jiangkou
# Processing Record 2 of Set 11 | champerico
# Processing Record 3 of Set 11 | sur
# Processing Record 4 of Set 11 | balaka
# Processing Record 5 of Set 11 | saint-augustin
# Processing Record 6 of Set 11 | vestmanna
# Processing Record 7 of Set 11 | marawi
# Processing Record 8 of Set 11 | anchorage
# Processing Record 9 of Set 11 | ales
# Processing Record 10 of Set 11 | burnie
# Processing Record 11 of Set 11 | ostrovnoy
# Processing Record 12 of Set 11 | tanout
# Processing Record 13 of Set 11 | srandakan
# Processing Record 14 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 15 of Set 11 | walla walla
# Processing Record 16 of Set 11 | myitkyina
# Processing Record 17 of Set 11 | peace river
# Processing Record 18 of Set 11 | vuktyl
# Processing Record 19 of Set 11 | tuatapere
# Processing Record 20 of Set 11 | abonnema
# Processing Record 21 of Set 11 | hulan ergi
# Processing Record 22 of Set 11 | marienburg
# Processing Record 23 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 11 | fairbanks
# Processing Record 25 of Set 11 | zaozerne
# Processing Record 26 of Set 11 | lorengau
# Processing Record 27 of Set 11 | bati
# Processing Record 28 of Set 11 | cervo
# Processing Record 29 of Set 11 | sault sainte marie
# Processing Record 30 of Set 11 | ust-kut
# Processing Record 31 of Set 11 | sorland
# Processing Record 32 of Set 11 | kafue
# Processing Record 33 of Set 11 | atyrau
# Processing Record 34 of Set 11 | arequipa
# Processing Record 35 of Set 11 | sandwick
# Processing Record 36 of Set 11 | waingapu
# Processing Record 37 of Set 11 | padilla
# Processing Record 38 of Set 11 | mnogovershinnyy
# Processing Record 39 of Set 11 | ahar
# Processing Record 40 of Set 11 | sandy springs
# Processing Record 41 of Set 11 | eydhafushi
# Processing Record 42 of Set 11 | alpena
# Processing Record 43 of Set 11 | tygda
# Processing Record 44 of Set 11 | mackay
# Processing Record 45 of Set 11 | carutapera
# Processing Record 46 of Set 11 | victor harbor
# Processing Record 47 of Set 11 | ouango
# Processing Record 48 of Set 11 | sao gabriel da cachoeira
# Processing Record 49 of Set 11 | quthing
# Processing Record 50 of Set 11 | voh
# Processing Record 1 of Set 12 | izvestkovyy
# Processing Record 2 of Set 12 | xudat
# Processing Record 3 of Set 12 | sehithwa
# Processing Record 4 of Set 12 | port lincoln
# Processing Record 5 of Set 12 | matamoros
# Processing Record 6 of Set 12 | tarko-sale
# Processing Record 7 of Set 12 | ndele
# Processing Record 8 of Set 12 | renqiu
# Processing Record 9 of Set 12 | shenjiamen
# Processing Record 10 of Set 12 | bonavista
# Processing Record 11 of Set 12 | puerto ayacucho
# Processing Record 12 of Set 12 | viransehir
# Processing Record 13 of Set 12 | batagay-alyta
# Processing Record 14 of Set 12 | primorsk
# Processing Record 15 of Set 12 | kropotkin
# Processing Record 16 of Set 12 | jijiga
# Processing Record 17 of Set 12 | ta khmau
# Processing Record 18 of Set 12 | parana
# Processing Record 19 of Set 12 | mandali
# Processing Record 20 of Set 12 | jelgava
# Processing Record 21 of Set 12 | ulaangom
# Processing Record 22 of Set 12 | proletariy
# Processing Record 23 of Set 12 | dingle
# Processing Record 24 of Set 12 | ukiah
# Processing Record 25 of Set 12 | tambopata
# Processing Record 26 of Set 12 | sungaipenuh
# Processing Record 27 of Set 12 | volksrust
# Processing Record 28 of Set 12 | finschhafen
# Processing Record 29 of Set 12 | zunheboto
# Processing Record 30 of Set 12 | myaundzha
# Processing Record 31 of Set 12 | najran
# Processing Record 32 of Set 12 | leningradskiy
# Processing Record 33 of Set 12 | hirara
# Processing Record 34 of Set 12 | sechura
# Processing Record 35 of Set 12 | bandar-e lengeh
# Processing Record 36 of Set 12 | leh
# Processing Record 37 of Set 12 | airai
# Processing Record 38 of Set 12 | marsabit
# Processing Record 39 of Set 12 | chake chake
# Processing Record 40 of Set 12 | gurlan
# Processing Record 41 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 12 | kargopol
# Processing Record 43 of Set 12 | pozo colorado
# Processing Record 44 of Set 12 | lanzhou
# Processing Record 45 of Set 12 | burayevo
# Processing Record 46 of Set 12 | riyadh
# Processing Record 47 of Set 12 | guerrero negro
# Processing Record 48 of Set 12 | miri
# Processing Record 49 of Set 12 | alot
# Processing Record 50 of Set 12 | grenville
# Processing Record 1 of Set 13 | gidam
# Processing Record 2 of Set 13 | korla
# Processing Record 3 of Set 13 | belaya gora
# Processing Record 4 of Set 13 | samandag
# Processing Record 5 of Set 13 | waverly
# Processing Record 6 of Set 13 | kemijarvi
# Processing Record 7 of Set 13 | petrovsk
# Processing Record 8 of Set 13 | nekhayevskiy
# Processing Record 9 of Set 13 | bontang
# Processing Record 10 of Set 13 | shahr-e babak
# Processing Record 11 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 13 | bere
# Processing Record 13 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 14 of Set 13 | cabinda
# Processing Record 15 of Set 13 | comodoro rivadavia
# Processing Record 16 of Set 13 | manhattan
# Processing Record 17 of Set 13 | mehamn
# Processing Record 18 of Set 13 | lasa
# Processing Record 19 of Set 13 | luba
# Processing Record 20 of Set 13 | kharan
# Processing Record 21 of Set 13 | muros
# Processing Record 22 of Set 13 | sistranda
# Processing Record 23 of Set 13 | tromso
# Processing Record 24 of Set 13 | marsh harbour
# Processing Record 25 of Set 13 | mazatlan
# Processing Record 26 of Set 13 | yumen
# Processing Record 27 of Set 13 | korsakovo
# Processing Record 28 of Set 13 | padang
# Processing Record 29 of Set 13 | klamath falls
# Processing Record 30 of Set 13 | zapolyarnyy
# Processing Record 31 of Set 13 | salinas
# Processing Record 32 of Set 13 | sokoto
# Processing Record 33 of Set 13 | matagami
# Processing Record 34 of Set 13 | ayorou
# Processing Record 35 of Set 13 | metro
# Processing Record 36 of Set 13 | sitka
# Processing Record 37 of Set 13 | mount isa
# Processing Record 38 of Set 13 | goroka
# Processing Record 39 of Set 13 | maniitsoq
# Processing Record 40 of Set 13 | sovetskiy
# Processing Record 41 of Set 13 | simpang
# Processing Record 42 of Set 13 | geraldton
# Processing Record 43 of Set 13 | okakarara
# Processing Record 44 of Set 13 | pochutla
# Processing Record 45 of Set 13 | itaituba
# Processing Record 46 of Set 13 | ejido
# Processing Record 47 of Set 13 | katsuura
# Processing Record 48 of Set 13 | aleysk
# Processing Record 49 of Set 13 | simbahan
# Processing Record 50 of Set 13 | coari
# Processing Record 1 of Set 14 | tatawin
# Processing Record 2 of Set 14 | taltal
# Processing Record 3 of Set 14 | tres passos
# Processing Record 4 of Set 14 | wanlaweyn
# Processing Record 5 of Set 14 | wasilla
# Processing Record 6 of Set 14 | neiafu
# Processing Record 7 of Set 14 | gasa
# Processing Record 8 of Set 14 | usinsk
# Processing Record 9 of Set 14 | outram
# Processing Record 10 of Set 14 | samana
# Processing Record 11 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 14 | barra patuca
# Processing Record 13 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 14 of Set 14 | perevoz
# Processing Record 15 of Set 14 | lubumbashi
# Processing Record 16 of Set 14 | nome
# Processing Record 17 of Set 14 | mont-saint-guibert
# Processing Record 18 of Set 14 | praia da vitoria
# Processing Record 19 of Set 14 | kushiro
# Processing Record 20 of Set 14 | adrar
# Processing Record 21 of Set 14 | agadir
# Processing Record 22 of Set 14 | nesoddtangen
# Processing Record 23 of Set 14 | provost
# Processing Record 24 of Set 14 | henties bay
# Processing Record 25 of Set 14 | rapid valley
# Processing Record 26 of Set 14 | mindelo
# Processing Record 27 of Set 14 | jackson
# Processing Record 28 of Set 14 | kostomuksha
# Processing Record 29 of Set 14 | kambove
# Processing Record 30 of Set 14 | santa cruz cabralia
# Processing Record 31 of Set 14 | zitlaltepec
# Processing Record 32 of Set 14 | ashland
# Processing Record 33 of Set 14 | asahikawa
# Processing Record 34 of Set 14 | phan thiet
# Processing Record 35 of Set 14 | abu samrah
# Processing Record 36 of Set 14 | lucapa
# Processing Record 37 of Set 14 | coahuayana
# Processing Record 38 of Set 14 | port macquarie
# Processing Record 39 of Set 14 | katherine
# Processing Record 40 of Set 14 | ambulu
# Processing Record 41 of Set 14 | totness
# Processing Record 42 of Set 14 | tazovskiy
# Processing Record 43 of Set 14 | huanan
# Processing Record 44 of Set 14 | male
# Processing Record 45 of Set 14 | quatre cocos
# Processing Record 46 of Set 14 | burla
# Processing Record 47 of Set 14 | verkhoyansk
# Processing Record 48 of Set 14 | samokov
# Processing Record 49 of Set 14 | ishigaki
# Processing Record 50 of Set 14 | kuopio
# Processing Record 1 of Set 15 | sola
# Processing Record 2 of Set 15 | semnan
# Processing Record 3 of Set 15 | meadow lake
# Processing Record 4 of Set 15 | povenets
# Processing Record 5 of Set 15 | glenluce
# Processing Record 6 of Set 15 | les cayes
# Processing Record 7 of Set 15 | moyale
# Processing Record 8 of Set 15 | caceres
# Processing Record 9 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 15 | tsabong
# Processing Record 11 of Set 15 | knysna
# Processing Record 12 of Set 15 | gorkovskoye
# City not found. Skipping...
# Processing Record 13 of Set 15 | noumea
# Processing Record 14 of Set 15 | willowmore
# Processing Record 15 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 15 | kousseri
# Processing Record 19 of Set 15 | new kensington
# Processing Record 20 of Set 15 | necochea
# Processing Record 21 of Set 15 | tucuman
# Processing Record 22 of Set 15 | troitskoye
# Processing Record 23 of Set 15 | montepuez
# Processing Record 24 of Set 15 | asfi
# Processing Record 25 of Set 15 | asau
# Processing Record 26 of Set 15 | linchuan
# City not found. Skipping...
# Processing Record 27 of Set 15 | biskamzha
# Processing Record 28 of Set 15 | feicheng
# Processing Record 29 of Set 15 | orcopampa
# Processing Record 30 of Set 15 | los llanos de aridane
# Processing Record 31 of Set 15 | saint anthony
# Processing Record 32 of Set 15 | raudeberg
# Processing Record 33 of Set 15 | morondava
# Processing Record 34 of Set 15 | guisa
# Processing Record 35 of Set 15 | kaeo
# Processing Record 36 of Set 15 | shahrud
# Processing Record 37 of Set 15 | iracoubo
# Processing Record 38 of Set 15 | doha
# Processing Record 39 of Set 15 | fallon
# Processing Record 40 of Set 15 | pontianak
# Processing Record 41 of Set 15 | gazojak
# Processing Record 42 of Set 15 | zalantun
# Processing Record 43 of Set 15 | colesberg
# Processing Record 44 of Set 15 | sturgis
# Processing Record 45 of Set 15 | mbaiki
# Processing Record 46 of Set 15 | ermelo
# Processing Record 47 of Set 15 | shahe
# Processing Record 48 of Set 15 | rawson
# Processing Record 49 of Set 15 | panjakent
# Processing Record 50 of Set 15 | kodinsk
# Processing Record 1 of Set 16 | chumikan
# Processing Record 2 of Set 16 | morros
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia -54.8000  -68.3000     42.46        87          40
# 1         Albany  42.6001  -73.9662     82.17        50          61
# 2           Hilo  19.7297 -155.0900     85.28        73           0
# 3        Fortuna  40.5982 -124.1573     60.91        61          20
# 4      Carnarvon -24.8667  113.6333     65.91        56           0
# 5  Makakilo City  21.3469 -158.0858     80.92        61           0
# 6         Nemuro  43.3236  145.5750     46.44        87          69
# 7   Punta Arenas -53.1500  -70.9167     48.31        71           0
# 8           Loei  17.4167  101.5000     72.12        85         100
# 9    New Norfolk -42.7826  147.0587     42.30        87          70
#
#    Wind Speed Country                 Date Current Description
# 0       19.57      AR  2022-06-13 18:26:37    scattered clouds
# 1        1.01      US  2022-06-13 18:25:11       broken clouds
# 2        4.61      US  2022-06-13 18:27:25           clear sky
# 3       17.27      US  2022-06-13 18:27:26          few clouds
# 4       13.69      AU  2022-06-13 18:27:26           clear sky
# 5       14.97      US  2022-06-13 18:27:27           clear sky
# 6        8.28      JP  2022-06-13 18:27:27       broken clouds
# 7       13.80      CL  2022-06-13 18:27:28           clear sky
# 8        3.40      TH  2022-06-13 18:27:28     overcast clouds
# 9        3.22      AU  2022-06-13 18:27:29       broken clouds

# %%
new_column_order = [ "City", "Country" ,"Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ushuaia      AR -54.8000  -68.3000     42.46        87          40
# 1     Albany      US  42.6001  -73.9662     82.17        50          61
# 2       Hilo      US  19.7297 -155.0900     85.28        73           0
# 3    Fortuna      US  40.5982 -124.1573     60.91        61          20
# 4  Carnarvon      AU -24.8667  113.6333     65.91        56           0
#
#    Wind Speed Current Description
# 0       19.57    scattered clouds
# 1        1.01       broken clouds
# 2        4.61           clear sky
# 3       17.27          few clouds
# 4       13.69           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
